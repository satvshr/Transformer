# %%
import pandas as pd
from nltk.tokenize import word_tokenize
import torch
import math
import re
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader, random_split
import numpy as np
from tokenizers import ByteLevelBPETokenizer
from tqdm import tqdm
import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("/kaggle/input/poetry/poetry.csv")

# %%
df = df.iloc[:len(df)]

# %%
pd.set_option('display.max_colwidth', None)
df.tail()
# Out:
#        Unnamed: 0  \
# 13849          13
# 13850          14
# 13851          15
# 13852           0
# 13853           1
#
#                                                                          Title  \
# 13849               \r\r\n                    1-800-FEAR\r\r\n
# 13850  \r\r\n                    The Death of Atahuallpa\r\r\n
# 13851              \r\r\n                    Poet's Wish\r\r\n
# 13852                        \r\r\n                    0\r\r\n
# 13853                        \r\r\n                    !\r\r\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Poem  \
# 13849  \r\r\nWe'd  like  to  talk  with  you  about  fear they  said  so\r\r\r\nmany  people  live  in  fear  these  days  they  drove  up\r\r\r\nall  four  of  them  in  a  small  car nice   boy  they  said\r\r\r\nbeautiful  dogs they  said  so  friendly  the  man  ahead\r\r\r\nof  the  woman  the other  two  waiting  in  the  drive  I\r\r\r\nwas  outside digging up the garden no one home I said\r\r\r\nwhat   are  you  selling   anyway  I'm   not  interested  I\r\r\r\nsaid  well  you  have  a  nice  day  they  said  here's  our\r\r\r\ncard  there's   a  phone  number  you  can  call  anytime\r\r\r\nany  other   houses  down  this  road  anyone  else   live\r\r\r\nhere  we'd  like  to  talk  to  them  about  living  in  fear\r\r\n
# 13850                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\r\n\r\r\n
# 13851                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   \r\r\n\r\r\n
# 13852                                                                                                                                                                                                         \r\r\n          Philosophic\r\r\nin its complex, ovoid emptiness,\r\r\na skillful pundit coined it as a sort\r\r\n    of stopgap doorstop for those\r\r\n           quaint equations           Romans never\r\r\ndreamt of. In form completely clever\r\r\nand discrete—a mirror come unsilvered,     loose watch face without the works,              a hollowed globe            from tip to toe\r\r\nunbroken, it evades the grappling\r\r\nhooks of mass, tilts the thin rim of no thing,     remains embryonic sum,             non-cogito.\r\r\n
# 13853                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    \r\r\nDear Writers, I’m compiling the first in what I hope is a series of publications I’m calling artists among artists. The theme for issue 1 is “Faggot Dinosaur.” I hope to hear from you! Thank you and best wishes.
#
#                     Poet  \
# 13849      Jody Gladding
# 13850  William Jay Smith
# 13851  William Jay Smith
# 13852  Hailey Leithauser
# 13853     Wendy Videlock
#
#                                                                                                           Tags
# 13849                                                               Living,Social Commentaries,Popular Culture
# 13850                                                                                                      NaN
# 13851                                                                                                      NaN
# 13852                                                                               Arts & Sciences,Philosophy
# 13853  Relationships,Gay, Lesbian, Queer,Arts & Sciences,Poetry & Poets,Social Commentaries,Gender & Sexuality

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Title           0
# Poem            0
# Poet            0
# Tags          955
# dtype: int64

# %%
df = df.drop(['Unnamed: 0', 'Tags', 'Poet', 'Title'], axis=1)

# %%
# df['Title'] = df['Title'].str.replace('\r', '')
df['Poem'] = df['Poem'].str.replace('\r', '')
# df['Title'] = df['Title'].str.replace('\n', '')
df['Poem'] = df['Poem'].str.strip('\n')

# %%
df.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Poem
# 13849  We'd  like  to  talk  with  you  about  fear they  said  so\nmany  people  live  in  fear  these  days  they  drove  up\nall  four  of  them  in  a  small  car nice   boy  they  said\nbeautiful  dogs they  said  so  friendly  the  man  ahead\nof  the  woman  the other  two  waiting  in  the  drive  I\nwas  outside digging up the garden no one home I said\nwhat   are  you  selling   anyway  I'm   not  interested  I\nsaid  well  you  have  a  nice  day  they  said  here's  our\ncard  there's   a  phone  number  you  can  call  anytime\nany  other   houses  down  this  road  anyone  else   live\nhere  we'd  like  to  talk  to  them  about  living  in  fear
# 13850
# 13851
# 13852                                                                                                                                                                                       Philosophic\nin its complex, ovoid emptiness,\na skillful pundit coined it as a sort\n    of stopgap doorstop for those\n           quaint equations           Romans never\ndreamt of. In form completely clever\nand discrete—a mirror come unsilvered,     loose watch face without the works,              a hollowed globe            from tip to toe\nunbroken, it evades the grappling\nhooks of mass, tilts the thin rim of no thing,     remains embryonic sum,             non-cogito.
# 13853                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Dear Writers, I’m compiling the first in what I hope is a series of publications I’m calling artists among artists. The theme for issue 1 is “Faggot Dinosaur.” I hope to hear from you! Thank you and best wishes.

# %%
# Lower case everything
# df['Title'] = df['Title'].str.lower()
df['Poem'] = df['Poem'].str.lower()

# Remove apostrophes and join the parts
# df['Title'] = df['Title'].str.replace("'", "", regex=False).str.replace("’", "", regex=False)
df['Poem'] = df['Poem'].str.replace("'", "", regex=False).str.replace("’", "", regex=False)

# %%
# Uncomment only when including encoder, until then let it be commented off
# Filter out rows where both 'Title' and 'Poem' have no alphabetic characters

# df = df[df.apply(lambda x: any(c.isalpha() for c in x['Title']) and
#                             any(c.isalpha() for c in x['Poem']), axis=1)]

# Filter out rows with no value (its not NaN its '' in this dataset)
df = df[df.apply(lambda x: any(c.isalpha() for c in x['Poem']), axis=1)]

# %%
# Make newline a special token
# df['Title'] = 'START ' + df['Title'] + ' END'
df['Poem'] = ' START ' + df['Poem'] + ' END '

df['Poem'] = df['Poem'].apply(lambda x: re.sub(r'\n', ' N ', x))

# %%
def remove_numeric_tokens(text):
    tokens = word_tokenize(text)
    # Filter tokens to exclude any that contain digits
    filtered_tokens = [token for token in tokens if not re.search(r'\d', token)]
    processed_text = ' '.join(filtered_tokens)
    return processed_text

df['Poem'] = df['Poem'].apply(remove_numeric_tokens)

# %%
df.tail()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Poem
# 13835                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            START dear writers , im compiling the first in what i hope is a series of publications im calling artists among artists . the theme for issue is “ faggot dinosaur. ” i hope to hear from you ! thank you and best wishes . END
# 13848  START the wise men will unlearn your name . N above your head no star will flame . N one weary sound will be the same— N the hoarse roar of the gale . N the shadows fall from your tired eyes N as your lone bedside candle dies , N for here the calendar breeds nights N till stores of candles fail . N what prompts this melancholy key ? N a long familiar melody . N it sounds again . so let it be . N let it sound from this night . N let it sound in my hour of death— N as gratefulness of eyes and lips N for that which sometimes makes us lift N our gaze to the far sky . N you glare in silence at the wall . N your stocking gapes : no gifts at all . N its clear that you are now too old N to trust in good saint nick ; N that its too late for miracles . N —but suddenly , lifting your eyes N to heavens light , you realize : N your life is a sheer gift . END
# 13849                                                                                                                                                                                                                                                                                       START wed like to talk with you about fear they said so N many people live in fear these days they drove up N all four of them in a small car nice boy they said N beautiful dogs they said so friendly the man ahead N of the woman the other two waiting in the drive i N was outside digging up the garden no one home i said N what are you selling anyway im not interested i N said well you have a nice day they said heres our N card theres a phone number you can call anytime N any other houses down this road anyone else live N here wed like to talk to them about living in fear END
# 13852                                                                                                                                                                                                                                                                                                                                                                                                                                    START philosophic N in its complex , ovoid emptiness , N a skillful pundit coined it as a sort N of stopgap doorstop for those N quaint equations romans never N dreamt of . in form completely clever N and discrete—a mirror come unsilvered , loose watch face without the works , a hollowed globe from tip to toe N unbroken , it evades the grappling N hooks of mass , tilts the thin rim of no thing , remains embryonic sum , non-cogito . END
# 13853                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            START dear writers , im compiling the first in what i hope is a series of publications im calling artists among artists . the theme for issue is “ faggot dinosaur. ” i hope to hear from you ! thank you and best wishes . END

# %%
df.isna().sum()
# Out:
# Poem    0
# dtype: int64

# %%
df.size
# Out:
# 13751

# %%
import sentencepiece as spm

# Saving poems to a file (required for tokenizer training)
poem_file = "poems.txt"
with open(poem_file, "w", encoding='utf-8') as file: 
    file.write(' \n'.join(df['Poem']))  # Use '\n' instead of ' N ' for SentencePiece

# Train the SentencePiece tokenizer on the poems
spm.SentencePieceTrainer.train(input=poem_file, model_prefix='poetry_model', vocab_size=32000)

# Load the trained SentencePiece model
sp = spm.SentencePieceProcessor()
sp.load("poetry_model.model")
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: poems.txt
#   input_format:
#   model_prefix: poetry_model
#   model_type: UNIGRAM
#   vocab_size: 32000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   d
# True
# ifferential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: poems.txt
# trainer_interface.cc(380) LOG(WARNING) Found too long line (4567 > 4192).
# trainer_interface.cc(382) LOG(WARNING) Too long lines are skipped in the training.
# trainer_interface.cc(383) LOG(WARNING) The maximum length can be changed with --max_sentence_length=<size> flag.
# trainer_interface.cc(409) LOG(INFO) Loaded all 13090 sentences
# trainer_interface.cc(416) LOG(INFO) Skipped 661 too long sentences.
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=14484062
# trainer_interface.cc(550) LOG(INFO) Done: 99.9533% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=51
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999533
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 13090 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=6869755
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 168974 seed sentencepieces
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 13090
# trainer_interface.cc(609) LOG(INFO) Done! 121212
# unigram_model_trainer.cc(602) LOG(INFO) Using 121212 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=56834 obj=10.0991 num_tokens=264078 num_tokens/piece=4.64648
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=47005 obj=7.97858 num_tokens=265322 num_tokens/piece=5.64455
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=35247 obj=7.94769 num_tokens=275592 num_tokens/piece=7.81888
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=35225 obj=7.93524 num_tokens=275829 num_tokens/piece=7.83049
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=35071 obj=7.93481 num_tokens=275883 num_tokens/piece=7.86641
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=35066 obj=7.93503 num_tokens=275899 num_tokens/piece=7.86799
# trainer_interface.cc(687) LOG(INFO) Saving model: poetry_model.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: poetry_model.vocab

# %%
# Tokenize a sentence
sentence = "damsel name is shakespeare"
encoded_tokens = sp.encode_as_ids(sentence)

print("Encoded tokens:", encoded_tokens)
# Decode the tokens back into words
decoded_sentence = sp.decode_ids(encoded_tokens)

print("Decoded sentence:", decoded_sentence)
# Out:
# Encoded tokens: [15456, 245, 20, 5011]
# Decoded sentence: damsel name is shakespeare

# %%
vocab_size = sp.get_piece_size()  # Number of unique words in the vocabulary
embedding_dim = 256
batch_size = 32 # Increase batch size if resources allow as it bring stabilization, 1 is very noisy
learning_rate = 0.001 # changed lr because maybe the embedding dim is too low and lr is too high so gradient is just bouncing around and not learning much
heads = 4
epochs = 4
seq_len = 200
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
with open(poem_file, "r", encoding='utf-8') as file: 
    f = file.read()
    
data = torch.tensor(sp.encode_as_ids(f))

# %%
def preprocessing(data, seq_len, pad_token):
    input_tensor = []
    target_tensor = []
    i = 0

    while i < len(data):
        input_tensor.append(torch.tensor(data[i:i+seq_len]))
        target_tensor.append(torch.tensor(data[i+1:i+seq_len+1]))
        i += seq_len
    
    input_tensor = torch.nn.utils.rnn.pad_sequence(input_tensor, padding_value=pad_token, batch_first=True)
    target_tensor = torch.nn.utils.rnn.pad_sequence(target_tensor, padding_value=pad_token, batch_first=True)
    
    return input_tensor, target_tensor

pad_token = sp.pad_id()
input_tensor, target_tensor = preprocessing(data, seq_len, pad_token)
# Out:
# /tmp/ipykernel_34/1982387253.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   input_tensor.append(torch.tensor(data[i:i+seq_len]))
# /tmp/ipykernel_34/1982387253.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_tensor.append(torch.tensor(data[i+1:i+seq_len+1]))

# %%
input_tensor.shape
# Out:
# torch.Size([28073, 200])

# %%
target_tensor.shape
# Out:
# torch.Size([28073, 200])

# %%
input_tensor[51]
# Out:
# tensor([   51,  3477,    13,     6,  2050, 19370,  1961,     3,     5,     3,
#             4,    51,  1054,    26,  6984,  3281,     3,     4,    24,  6816,
#          2266,    13,     6,  1435,     3,     5,     3,     4,    51, 14239,
#            17,  3176,   158,  9718,  3900,    90,   965,     3,     5,     3,
#             4,     3,     4,   130,   320,   118,   983,     3,     4,     3,
#             4,    71,    20,   108,   113,   730,     3,     4,     8,   275,
#           730,     3,     4,     3,     4,   118,   983,     3,     4,     3,
#             4,    13,  2553,  1984,     3,     4,    13,   325,  1984,     3,
#             4,  1480,    68,    10,   753,   146,     3,     4,  3035,    90,
#             6,  4018,     3,     4,     3,     4,     6,   182,    65,  1403,
#             3,     4,     6,   182,    65,   860,     3,     4,  1403,    56,
#          1508,    12,   860,     3,     4,     3,     4,    63,    56,    53,
#           717,     3,    47,     3,     4,    63,    56,    53,   717,     3,
#            47,     3,     4,     3,     4,   201,    88,     3,     5,   510,
#           645,     3,     4,  3388,    25,    68,    10,    55,  1823,     7,
#             3,     4,     3,     4,   201,    88,     3,     5,  8220,     3,
#             4,  2012,    24,    55,  1279,     7,     3,     4,     3,     4,
#           201,    88,     3,     5, 15100,     7,     3,     4,  1043,    55,
#          3736,     3,     4,     8,  2073,   762,  2073,   762,     3,     4,
#             3,     4, 31229,    11,     3,     5, 18168,    11,     3,     5])

# %%
target_tensor[51]
# Out:
# tensor([ 3477,    13,     6,  2050, 19370,  1961,     3,     5,     3,     4,
#            51,  1054,    26,  6984,  3281,     3,     4,    24,  6816,  2266,
#            13,     6,  1435,     3,     5,     3,     4,    51, 14239,    17,
#          3176,   158,  9718,  3900,    90,   965,     3,     5,     3,     4,
#             3,     4,   130,   320,   118,   983,     3,     4,     3,     4,
#            71,    20,   108,   113,   730,     3,     4,     8,   275,   730,
#             3,     4,     3,     4,   118,   983,     3,     4,     3,     4,
#            13,  2553,  1984,     3,     4,    13,   325,  1984,     3,     4,
#          1480,    68,    10,   753,   146,     3,     4,  3035,    90,     6,
#          4018,     3,     4,     3,     4,     6,   182,    65,  1403,     3,
#             4,     6,   182,    65,   860,     3,     4,  1403,    56,  1508,
#            12,   860,     3,     4,     3,     4,    63,    56,    53,   717,
#             3,    47,     3,     4,    63,    56,    53,   717,     3,    47,
#             3,     4,     3,     4,   201,    88,     3,     5,   510,   645,
#             3,     4,  3388,    25,    68,    10,    55,  1823,     7,     3,
#             4,     3,     4,   201,    88,     3,     5,  8220,     3,     4,
#          2012,    24,    55,  1279,     7,     3,     4,     3,     4,   201,
#            88,     3,     5, 15100,     7,     3,     4,  1043,    55,  3736,
#             3,     4,     8,  2073,   762,  2073,   762,     3,     4,     3,
#             4, 31229,    11,     3,     5, 18168,    11,     3,     5,     3])

# %%
dataset = TensorDataset(input_tensor, target_tensor)

train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)  # Don't shuffle validation data

# %%
def count_batches(loader, name):
    n_batches = 0
    for i in loader:
        n_batches+=1

    print(f"Number of batches in {name}: ",n_batches)

count_batches(train_loader, "train_loader")
count_batches(val_loader, "val_loader")
# Out:
# Number of batches in train_loader:  790
# Number of batches in val_loader:  88

# %%
pad_token
# Out:
# -1

# %%
class WordEmbedder(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        self.embeddings = nn.Embedding(num_embeddings=vocab_size, embedding_dim=embedding_dim)

    def forward(self, x):
        return self.embeddings(x)

# %%
# Now that we have successfully trained our word embedding layer, time to make our positional matrix, which we will make using the formula mentioned in the paper
def positional_encoding(seq_len, embedding_dim, device=device):
        positional_encoding = torch.zeros(seq_len, embedding_dim)
        position = torch.arange(0, seq_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, embedding_dim, 2).float() * (-torch.log(torch.tensor(10000.0)) / embedding_dim))
        positional_encoding[:, 0::2] = torch.sin(position * div_term)
        positional_encoding[:, 1::2] = torch.cos(position * div_term)
        return positional_encoding

# %%
positional_encoding(seq_len, embedding_dim).unsqueeze(0).expand(batch_size, -1, -1).shape
# Out:
# torch.Size([32, 200, 256])

# %%
# Time to make the Multi-head Self Attention block
class MultiHeadSelfAttention(nn.Module):
    def __init__(self, heads, embedding_dim):
        super(MultiHeadSelfAttention, self).__init__()
        self.heads = heads

        # 3 Linear Layers for Q, K and V
        self.w_q = nn.Linear(embedding_dim, embedding_dim)
        self.w_k = nn.Linear(embedding_dim, embedding_dim)
        self.w_v = nn.Linear(embedding_dim, embedding_dim)

        # Since the feature or embedding dimension is typically the last dimension
        self.softmax = nn.Softmax(dim=-1)

        # Last Linear layer for the attention
        self.w_a = nn.Linear(embedding_dim, embedding_dim)

    def forward(self, embedding_vector):
        batch_size, seq_len, embedding_dim = embedding_vector.size()
        # Compute Q, K, and V
        Q = self.w_q(embedding_vector)
        K = self.w_k(embedding_vector)
        V = self.w_v(embedding_vector)

        # Seperate into heads
        head_dim = embedding_dim // self.heads
        Q = Q.view(batch_size, self.heads, seq_len, head_dim)
        K = K.view(batch_size, self.heads, seq_len, head_dim)
        V = V.view(batch_size, self.heads, seq_len, head_dim)

        # Calculate attention
        attention = torch.matmul(self.softmax(torch.matmul(Q, K.transpose(-1, -2)) / torch.sqrt(torch.tensor(embedding_dim))), V)

        # Concatenating the attention heads (Transposing for correct concatenation)
        attention = attention.transpose(1, 2).reshape(batch_size, seq_len, embedding_dim)
        output = self.w_a(attention)
        # print("Shape after attention:", output.shape)
        # num_active_elements = torch.gt(output, -1).sum().item()
        # total_elements = output.numel()
        # print(f"active  att: {num_active_elements}/{total_elements}")
        return output

# %%
# Time to make the Masked Multi-head Self Attention block
class MaskedMultiHeadSelfAttention(nn.Module):
    def __init__(self, heads, embedding_dim):
        super(MaskedMultiHeadSelfAttention, self).__init__()
        self.heads = heads

        # 3 Linear Layers for Q, K and V
        self.w_q = nn.Linear(embedding_dim, embedding_dim)
        self.w_k = nn.Linear(embedding_dim, embedding_dim)
        self.w_v = nn.Linear(embedding_dim, embedding_dim)

        # Since the feature or embedding dimension is typically the last dimension
        self.softmax = nn.Softmax(dim=-1)

        # Last Linear layer for the attention
        self.w_a = nn.Linear(embedding_dim, embedding_dim)

    def forward(self, embedding_vector):
        batch_size, seq_len, embedding_dim = embedding_vector.size()
        # Compute Q, K, and V
        Q = self.w_q(embedding_vector)
        K = self.w_k(embedding_vector)
        V = self.w_v(embedding_vector)

        # Seperate into heads
        head_dim = embedding_dim // self.heads
        Q = Q.view(batch_size, self.heads, seq_len, head_dim)
        K = K.view(batch_size, self.heads, seq_len, head_dim)
        V = V.view(batch_size, self.heads, seq_len, head_dim)

        # Create a mask for masking the attention score
        mask = torch.triu(torch.ones(seq_len, seq_len, dtype=torch.bool), diagonal=1).unsqueeze(0).unsqueeze(0).expand(batch_size, self.heads, -1, -1).to(device)
        value_to_fill = float('-inf')

        # Calculate attention (including mask)
        attention = torch.matmul(self.softmax(torch.matmul(Q, K.transpose(-1, -2)).masked_fill(mask, value_to_fill) / torch.sqrt(torch.tensor(embedding_dim))), V)
        # Concatenating the attention heads (Transposing for correct concatenation)
        attention = attention.transpose(1, 2).reshape(batch_size, seq_len, embedding_dim)
        output = self.w_a(attention)
        # print("Shape after mask:", output.shape)
        # num_active_elements = torch.gt(output, -1).sum().item()
        # total_elements = output.numel()
        # print(f"active masked: {num_active_elements}/{total_elements}")
        return output

# %%
class AddNorm(nn.Module):
    def __init__(self, n_features):
        super(AddNorm, self).__init__()
        # Layer Norm will normalize the last dimension of the matrix
        self.norm = nn.LayerNorm(n_features)

    def forward(self, original, modified):
        return self.norm(original + modified)

# %%
class FeedForward(nn.Module):
    def __init__(self, embedding_dim):
        super(FeedForward, self).__init__()
        # Normally nn.Linear(embedding_dim, embedding_dim * 4) for expressiveness, we will change it if we have the resources to do so
        self.lr1 = nn.Linear(embedding_dim, embedding_dim)
        self.relu = nn.ReLU()
        self.lr2 = nn.Linear(embedding_dim, embedding_dim)

    def forward(self, x):
        x = self.lr1(x)
        x = self.relu(x)
        x = self.lr2(x)
        # num_active_elements = torch.gt(x, -1).sum().item()
        # total_elements = x.numel()
        # print(f"active feedforward: {num_active_elements}/{total_elements}")
        return x

# %%
# Time to build the Decoder
class Decoder(nn.Module):
    def __init__(self, vocab_size, embedding_dim, batch_size, seq_len, heads):
        super(Decoder, self).__init__()
        self.word_embedder = WordEmbedder(vocab_size, embedding_dim)
        self.poitional_encoding = positional_encoding(seq_len, embedding_dim).unsqueeze(0).expand(batch_size, -1, -1).to(device)
        self.masked_attention = MaskedMultiHeadSelfAttention(heads, embedding_dim)
        self.add_norm1 = AddNorm(embedding_dim)
        self.attention = MultiHeadSelfAttention(heads, embedding_dim)
        self.add_norm2 = AddNorm(embedding_dim)
        self.feed_forward = FeedForward(embedding_dim)
        self.add_norm3 = AddNorm(embedding_dim)
        self.linear = nn.Linear(embedding_dim, vocab_size)

    def forward(self, x):
        # print("Shape before word embedder:", x.shape)
        x = self.word_embedder(x)
        # print("Shape after word embedder/before positional:", x.shape)
        # num_active_elements = torch.gt(x, -1).sum().item()
        # total_elements = x.numel()
        # print(f"active word embedder: {num_active_elements}/{total_elements}")
        x += self.poitional_encoding
        # print("Shape after positional:", x.shape)
        # num_active_elements = torch.gt(x, -1).sum().item()
        # total_elements = x.numel()
        # print(f"active positional_encoding: {num_active_elements}/{total_elements}")
#         print(x.shape)
        x = self.add_norm1(x, self.masked_attention(x))
        # print("Shape after addnorm1:", x.shape)
        # num_active_elements = torch.gt(x, -1).sum().item()
        # total_elements = x.numel()
        # print(f"active add_norm1: {num_active_elements}/{total_elements}")
#         print(x.shape)
        x = self.add_norm2(x, self.attention(x))
        # print("Shape after addnorm2:", x.shape)
        # num_active_elements = torch.gt(x, -1).sum().item()
        # total_elements = x.numel()
        # print(f"active add_nor2: {num_active_elements}/{total_elements}")
#         print(x.shape)
        x = self.add_norm3(x, self.feed_forward(x))
        # print("Shape after addnorm3:", x.shape)
        # num_active_elements = torch.gt(x, -1).sum().item()
        # total_elements = x.numel()
        # print(f"active add_norm3: {num_active_elements}/{total_elements}")
#         print(x.shape)
        # print("Shape before linear:", x.shape)
        logits = self.linear(x)
        # print("Shape after linear:", logits.shape)
        # num_active_elements = torch.gt(logits, 0).sum().item()
        # total_elements = logits.numel()
        # print(f"active linear: {num_active_elements}/{total_elements}")
        return logits

# %%
model = Decoder(vocab_size, embedding_dim, batch_size, seq_len, heads).to(device)
model
# Out:
# Decoder(
#   (word_embedder): WordEmbedder(
#     (embeddings): Embedding(32000, 256)
#   )
#   (masked_attention): MaskedMultiHeadSelfAttention(
#     (w_q): Linear(in_features=256, out_features=256, bias=True)
#     (w_k): Linear(in_features=256, out_features=256, bias=True)
#     (w_v): Linear(in_features=256, out_features=256, bias=True)
#     (softmax): Softmax(dim=-1)
#     (w_a): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (add_norm1): AddNorm(
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   )
#   (attention): MultiHeadSelfAttention(
#     (w_q): Linear(in_features=256, out_features=256, bias=True)
#     (w_k): Linear(in_features=256, out_features=256, bias=True)
#     (w_v): Linear(in_features=256, out_features=256, bias=True)
#     (softmax): Softmax(dim=-1)
#     (w_a): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (add_norm2): AddNorm(
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   )
#   (feed_forward): FeedForward(
#     (lr1): Linear(in_features=256, out_features=256, bias=True)
#     (relu): ReLU()
#     (lr2): Linear(in_features=256, out_features=256, bias=True)
#   )
#   (add_norm3): AddNorm(
#     (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   )
#   (linear): Linear(in_features=256, out_features=32000, bias=True)
# )

# %%
# Initialize our optimizer and loss function
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss(ignore_index=pad_token)

# %%
def generate_poem(model, start_sequence, tokenizer=sp, max_length=300):
    model.eval()
    tokens = sp.encode_as_ids(start_sequence)
    generated_ids = [sp.piece_to_id("START")] + tokens
    input_seq = torch.tensor([generated_ids], dtype=torch.long).to(device)

    for _ in range(max_length):
        with torch.no_grad():
            logits = model(input_seq)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            next_token_id = idx_next.item()

            # Append the newly generated token to the input sequence
            input_seq = torch.cat([input_seq, torch.tensor([next_token_id], dtype=torch.long).unsqueeze(0).to(device)], dim=1)
            generated_ids.append(next_token_id)

            if next_token_id == sp.piece_to_id("END"):
                break

    generated_text = sp.decode_ids(generated_ids)
    return generated_text

# %%
def train_epoch(data_loader, model, optimizer, loss_fn, device, pad_token):
    model.train()
    total_loss = 0.0

    # Wrap your data loader with tqdm for a progress bar
    progress_bar = tqdm(train_loader, desc="Training", leave=True)

    for input_batch, target_batch in progress_bar:
        input_data = input_batch.to(device)
        target_data = target_batch.to(device)
        optimizer.zero_grad()

        # Forward pass
        probs = model(input_data)

        # Reshape input and output to correct format for loss calculation
        B, T, C = probs.shape
        probs = probs.view(B * T, C)
        target_data = target_data.view(-1)

        # Calculate loss
        loss = loss_fn(probs, target_data)

        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        # Update the progress bar with the current batch loss
        progress_bar.set_postfix(loss=loss.item())

    return total_loss / len(data_loader)  # Average loss

def validate_epoch(data_loader, model, loss_fn, device, pad_token):
    model.eval()
    total_loss = 0.0

    with torch.no_grad():
    # Wrap your data loader with tqdm for a progress bar
        progress_bar = tqdm(val_loader, desc="Validation", leave=True)

        for input_batch, target_batch in progress_bar:
            input_data = input_batch.to(device)
            target_data = target_batch.to(device)

            # Forward pass
            probs = model(input_data)

            # Reshape input and output to correct format for loss calculation
            B, T, C = probs.shape
            probs = probs.view(B * T, C)
            target_data = target_data.view(-1)

                # Calculate loss
            loss = loss_fn(probs, target_data)

            total_loss += loss.item()

            # Update the progress bar with the current batch loss (optional)
            # progress_bar.set_postfix(loss=loss.item())

        return total_loss / len(data_loader)  # Average loss

epoch_losses = []
validation_losses = []

for epoch in range(epochs):
    print(f"Starting Epoch {epoch + 1}/{epochs}")
    train_loss = train_epoch(train_loader, model, optimizer, loss_fn, device, pad_token)
    val_loss = validate_epoch(val_loader, model, loss_fn, device, pad_token)
    epoch_losses.append(train_loss)
    validation_losses.append(val_loss)
    print(f"Epoch {epoch + 1}, Train Loss: {train_loss:.15f}, Validation Loss: {val_loss:.15f}")
    print(generate_poem(model, "flower"))
# Out:
# Starting Epoch 1/4
# Training:  49%|████▉     | 391/790 [00:30<00:30, 13.17it/s, loss=3.91]/usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [4,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [117,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [116,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [22,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [172,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /usr/local/src/pytorch/aten/src/ATen/native/cuda/Indexing.cu:1292: indexSelectLargeIndex: block: [247,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# Training:  50%|████▉     | 392/790 [00:30<00:31, 12.77it/s, loss=3.91]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[50], line 68
#      66 for epoch in range(epochs):
#      67     print(f"Starting Epoch {epoch + 1}/{epochs}")
# ---> 68     train_loss = train_epoch(train_loader, model, optimizer, loss_fn, device, pad_token)
#      69     val_loss = validate_epoch(val_loader, model, loss_fn, device, pad_token)
#      70     epoch_losses.append(train_loss)
#
# Cell In[50], line 14, in train_epoch(data_loader, model, optimizer, loss_fn, device, pad_token)
#      11 optimizer.zero_grad()
#      13 # Forward pass
# ---> 14 probs = model(input_data)
#      16 # Reshape input and output to correct format for loss calculation
#      17 B, T, C = probs.shape
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[46], line 28, in Decoder.forward(self, x)
#      22         x += self.poitional_encoding
#      23         # print("Shape after positional:", x.shape)
#      24         # num_active_elements = torch.gt(x, -1).sum().item()
#      25         # total_elements = x.numel()
#      26         # print(f"active positional_encoding: {num_active_elements}/{total_elements}")
#      27 #         print(x.shape)
# ---> 28         x = self.add_norm1(x, self.masked_attention(x))
#      29         # print("Shape after addnorm1:", x.shape)
#      30         # num_active_elements = torch.gt(x, -1).sum().item()
#      31         # total_elements = x.numel()
#      32         # print(f"active add_norm1: {num_active_elements}/{total_elements}")
#      33 #         print(x.shape)
#      34         x = self.add_norm2(x, self.attention(x))
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[36], line 32, in MaskedMultiHeadSelfAttention.forward(self, embedding_vector)
#      29 V = V.view(batch_size, self.heads, seq_len, head_dim)
#      31 # Create a mask for masking the attention score
# ---> 32 mask = torch.triu(torch.ones(seq_len, seq_len, dtype=torch.bool), diagonal=1).unsqueeze(0).unsqueeze(0).expand(batch_size, self.heads, -1, -1).to(device)
#      33 value_to_fill = float('-inf')
#      35 # Calculate attention (including mask)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
plt.plot(range(1, epochs + 1), epoch_losses, validation_losses) 
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Training Loss Over Epochs")
plt.show()

# %%
len(validation_losses)

# %%
plt.plot(range(epochs-5), epoch_losses[5:], label='Training Loss')
plt.plot(range(epochs-5), validation_losses[5:], label='Validation Loss')
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.title("Training Loss Over Epochs")
plt.show()

# %%
model_path = "model_weights.pth"
torch.save(model.state_dict(), model_path)

# %%
model.load_state_dict(torch.load("model_weights.pth"))
model.eval()

# %%
start_sequence = "flower"
poem = generate_poem(model, start_sequence)
print(poem)
